# %% [markdown]
# # Bevezetés a tudományos programozásba
#
# ## 2. Előadás
#
#
# ### 2025. szeptember 16.

# %% [markdown]
# # Beépített típusok és operátorok
#  - Boolean  (Igazság)
#  - Numerikus (Szám)
#  - String  (Szöveg)

# %% [markdown]
# ### boolean típus
#
# - két boolean érték: `True` és `False`

# %% [markdown]
# <div align="center">
#   <img src="BoolMeme.jpg" width="750" height="750">
# </div>

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
x = False
type(x)
# Out:
# bool

# %% [markdown]
# ## Operátor
#
# speciális szimbólum (vagy kulcsszó), ami egy műveletet hajt végre egy vagy több tagon

# %% [markdown]
# ### boolean operátorok
#
# - három boolean operátor van: `and`, `or` and `not`

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
not False
# Out:
# True

# %% [markdown]
# ## Numerikus típusok
#
# - három numerikus típus: `int`, `float` and `complex`
# - a kezdeti értéktől függ az objektum típusa

# %%
i = 2
f = 1.2
c = 1+2j

type(i), type(f), type(c)
# Out:
# (int, float, complex)

# %% [markdown]
# - implicit konverzió működik köztük aritmetikai műveletek esetén
# - az eredmény típusa mindig a legkevesebb információ veszteséggel járó típus

# %%
c2 = i + c
print(c2, type(c2))
# Out:
# (3+2j) <class 'complex'>

# %% [markdown]
# ### Tartomány
#
# - Az egészek tetszőleges méretűek lehetnek, csak a számítógép hardver oldala szab határt.
# - Python 2-ben más a helyzet!

# %%
2**100000
# Out:
# ...

# %%
type(2**63 + 1)
# Out:
# int

# %% [markdown]
# ## float, complex
#
# - floatok általában a C double típusán alapszanak, így a precizitásuk véges
# - komplex számok pedig két floatot használnak.
# - pontos információt a  `sys.float_info` parancs segítségével kapunk

# %%
import sys
sys.float_info
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %%
sys.int_info
# Out:
# sys.int_info(bits_per_digit=30, sizeof_digit=4)

# %% [markdown]
# ## Aritmetikai operátorok

# %% [markdown]
# +, -, \*, /, %, //, \**

# %% [markdown]
# ## Összehasonlító operátorok
#
# Összehasonlít két értéket, és egy boolean-t ad vissza.
#
# ==, !=, <, >, <=, >=

# %%
x = 23
x < 24, x >= 22
# Out:
# (True, True)

# %% [markdown]
# Össze is lehet őket láncolni

# %%
23 < x and x < 100
# Out:
# False

# %%
23 <= x < 100
# Out:
# True

# %% [markdown]
# ## Python-ban minden objektum (Everything is an object)
#
#
# Erre később visszatérünk az objektumorientált fejezetnél. Egyelőre legyen elég annyi, hogy bármit csinálunk / hozunk létre Pythonban, az eredmény egy `objektum`, melynek általában vannak attribútumai és metódusai. A továbbiakban nem fogjuk ezeket a fogalmakat pontosan definiálni, nagyjából a következőket értjük majd alatta:
#
# * attribútum: mező, tulajdonság, stb. (attribute, field, property)
# * metódus: a tartalmazott adaton (is) értelmezett művelet  (method)

# %% [markdown]
# <div align="center">
#   <img src="methods_of_an_int.png" width="200" height="200">
# </div>

# %%
a = 1

print(dir(a))
# Out:
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'as_integer_ratio', 'bit_count', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']

# %%
a.__add__(2)
# Out:
# 3

# %%
a.__abs__()
# Out:
# 1

# %%
z = 1 + 2j

print(dir(z))
# Out:
# ['__abs__', '__add__', '__bool__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__mul__', '__ne__', '__neg__', '__new__', '__pos__', '__pow__', '__radd__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__rpow__', '__rsub__', '__rtruediv__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', 'conjugate', 'imag', 'real']

# %%
print(z.imag)

print(z.real)
# Out:
# 2.0
# 1.0

# %%
print(z.conjugate())
# Out:
# (1-2j)

# %% [markdown]
# ## Értékadás (Assignment)
#
# Kicsit más mint a legtöbb nyelvben:
#
# - C++-ban `i = 2` kb azt jelenti, hogy a típussal rendelkező i változó megkapja a 2 érték másolatát.
# - Python `i = 2` kb azt jelenti hogy az i név kap egy referenciát egy egy numerikus objektumhoz, aminek az értéke 2.
#
# - mindig a jobb oldal értékelődik ki először, majd pedig a bal oldali név kap egy referenciát a jobb oldali értékhez
#
# Az `id` függvény visszaadja az objektum egyedi azonosító számát. (Miért lehet gond az id használatából?)

# %%
i = 2
print(id(i))

i = 3
print(id(i))
# Out:
# 140561759764752
# 140561759764784

# %% [markdown]
# Az id-kat összehasonlíthatjuk az `is` paranccsal.

# %%
a = 2025
b = 2025


print("A két változó értéke egyenlő:", a == b)
print("A két változó által mutatott objektum azonos:", a is b)
print("A nemegyenlőség vizsgálata a != operátorral történik:", a != 0)
# Out:
# A két változó értéke egyenlő: True
# A két változó által mutatott objektum azonos: False
# A nemegyenlőség vizsgálata a != operátorral történik: True

# %%
a=25
b=25
a is b
# Out:
# True

# %%
a=300
b=300
a is b
# Out:
# False

# %%
x = 1

x + 1

print(x)

x = x + 1
# Out:
# 1

# %% [markdown]
# ### Expressions vs Statements
#
# Expression (kifejezés)
#
# A kifejezés olyan kódrészlet, amit a Python ki tud értékelni
#
# * Mindig visszaad egy értéket
# * Beágyazható nagyobb kifejezésekbe vagy utasításokba
# * Önmagában nem változtatja meg a program állapotát
#
# Statement (utasítás)
#
# Az utasítás egy parancs, amit a Python végre tud hajtani
#
# * Tartalmazhat kifejezéseket, de önmagában nem egy érték
# * Megváltoztatja a program állapotát (pl. változót hoz létre)

# %%
x += 1

print(x)

x *= 2

print(x)

x -= 7

print(x)
# Out:
# 3
# 6
# -1

# %% [markdown]
# # Karakterláncok (Strings)

# %%
s1 = "Hello, world!"

s2 = 'Hello, world!'

len(s1)
# Out:
# 13

# %%
print(s1.upper())

print(s1.islower())
# Out:
# HELLO, WORLD!
# False

# %% [markdown]
# Egy konkrét string-en rengeteg metódus van definiálva. Ezekről többféleképpen is lehet leírást kapni.

# %%
help(s1.capitalize)
# Out:
# Help on built-in function capitalize:
#
# capitalize() method of builtins.str instance
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the rest lower
#     case.

# %%
s1.capitalize?
# Out:
# Signature: s1.capitalize()
# Docstring:
# Return a capitalized version of the string.
#
# More specifically, make the first character have upper case and the rest lower
# case.
# Type:      builtin_function_or_method

# %%
name = "wiNNeTou"

name.capitalize()
# Out:
# 'Winnetou'

# %%
s = "abc"

print(s[0])    # Pythonban az indexelés mindig 0-tól kezdődik!
print(s[1])
print(s[2])
# Out:
# a
# b
# c

# %%
s[0] = "x"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 s[0] = "x"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ## Mutable / immutable objektumok
#
# Mutable: módosítható
#
# * az objektum tartalma meg tud változni a létrehozása után is
#
# Immutable (nem módosítható)
#
# * minden “módosítás” valójában egy új objektumot hoz létre

# %% [markdown]
# **Immutable típusok:**
#
# * Számok
# * Szöveg

# %%
x = 5
print(id(x))   
x += 1         
print(id(x))
# Out:
# 140561759764848
# 140561759764880

# %%
print(s.replace("a", "x"))

print(s)
# Out:
# xbc
# abc

# %% [markdown]
# A Python erősen típusos nyelv, ami azt jelenti, hogy futásidő alatt nem történnek implicit módon meglepő típuskonverziók. Vannak olyan nyelvek, ahol igen, egy sztringből hirtelen szám lesz, ha a művelet így válik értelmessé.
#
# ```PHP
# $s = "10";
# $a = 20;
#
# print $s + $a;
# ```
#
# Pythonban ez nem működik: ```"10" + 20 = ???```

# %%
"10" + 20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 "10" + 20
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # Kódblokkok (Code blocks)

# %% [markdown]
# <div align="center">
#   <img src="IndentationMeme.webp" width="500" height="500">
# </div>

# %% [markdown]
# Pythonban a kódblokkokat indentációval (bekezdéssel) hozzuk létre. A bekezdés behúzásának mértéke megállapodás szerint 4. A külalakot tekintve Pythonban a PEP-8 (Python Enhancement Proposals) néven ismert stílusgyűjtemény ad útmutatást. Ez olyan stilisztikai megállapodások gyűjteménye, amelyet illik figyelembevenni kódíráskor.
#
#
# [PEP-8](https://peps.python.org/pep-0008/): *This document gives coding conventions for the Python code comprising the standard library in the main Python distribution.*

# %% [markdown]
# ## Feltételes elágazások: if - elif - else (Conditional branching)

# %% [markdown]
# Ha a feltétel igaz, csináljunk valamit. (Feltételes utasítás)
#
#
# ```python
# if condition:
#     do_something()
# ```

# %%
a = 2025

if a % 7 == 0:
    a = a // 2
    
print(a)
# Out:
# 2025

# %% [markdown]
# Az `elif` ágak és az `else` ág opcionális. Amelyik feltétel először teljesül, az az ág hajtódik végre, a többi nem. Ha egyik sem teljesül és van `else` ág, akkor az `else` ág hajtódik végre.
#
# ```python
# if condition_1:
#     do_something_1()
# elif condition_2:
#     do_something_2()
# # ...
# elif condition_n:
#     do_something_n()
# else:
#     do_something_else()
# ```

# %%
a = 20

if a % 3 == 0:
    print("A")
    
if a % 2 == 0:
    print("B")
    
if a % 5 == 0:
    print("C")
# Out:
# B
# C

# %% [markdown]
# ```python
# if a % 3 == 0:
#     print("A")
#
# elif a % 2 == 0:
#     print("B")
#
# elif a % 5 == 0:
#     print("C")
#
# else:
#     print("D")
# ```
#
# Mit fog kiírni?
#
# * B, C
# * B
# * C

# %%
a = 20

if a % 3 == 0:
    print("A")
    
elif a % 2 == 0:
    print("B")
    
elif a % 5 == 0:
    print("C")

else:
    print("D")
# Out:
# B

# %%
a = 10

if 0 <= a and a <= 100:
    a = a + 1

print(a)
# Out:
# 11

# %%
# Indentált blokkban definiált változók a blokkon kívül is látszanak, 
#eltérően egyes nyelvektől.

a = 10

if 0 <= a and a <= 100:
    a = a + 1
    b = 1

print(b)
# Out:
# 1

# %%
if True:
    print("This is always true.")

else:
    print("Impossible to reach this branch")
# Out:
# This is always true.

# %%
year = 2025

if year % 4 == 0 and (year % 100 != 0 or (year % 100 == 0 
                                          and year % 400 == 0)):
    print(f"Year {year} is a leap year.")

else:
    print(f"Year {year} is not a leap year.")
# Out:
# Year 2025 is not a leap year.

# %% [markdown]
# Nem csak logikai kifejezéseknek van logikai értéke, hanem számoknak, string-eknek, sőt, mint azt később látni fogjuk, mindenféle Python collection-nek (adatszerkezetnek) is van logikai értéke.
#
# Ezen kívül, akár saját magunk által definiált adatszerkezetnek, osztálypéldánynak is tulajdoníthatunk (azaz megadhatunk) logikai értéket, amint ezt majd az objektumorientált részben látni fogjuk.

# %%
if -2:
    print("This?")
    
else:
    print("Or that?")
# Out:
# This?

# %%
if "Hello":
    print("Hi, mate!")
    
else:
    print("Sorry, I do not know you.")
# Out:
# Hi, mate!

# %%
a = 10
condition = (a % 2 == 0)

print(type(condition))
print(condition)
# Out:
# <class 'bool'>
# True

# %%
if condition == True:
    print("This is true.")
    
if condition is True:
    print("This is true.")

# Mivel magának a feltételnek már van logikai értéke, 
#az előző kettő módszert inkább ne használjuk

if condition:
    print("This is true.")
# Out:
# This is true.
# This is true.
# This is true.

# %%
if condition:
    message = "a is even"
else:
    message = "a is odd"
    
message
# Out:
# 'a is even'

# %% [markdown]
# Más nyelvekben létezik ternáris operátor, pl.
# ```julia
# x = 10 % 2 == 0 ? "Yes" : "No"
# ```
#
# Pythonban egy ahhoz hasonló feltételes kifejezés létezik, amely azonban kevés kivételtől eltekintve nem ajánlott, csak ha a kifejezés rövid, mert nehezen olvasható.

# %%
# if-expression

n = 2025

message = "Yes" if n % 2 == 0 else "No"

print(message)
# Out:
# No

# %% [markdown]
# # Ciklusok (Loops), Intervallumok (Range)
#
# range: beépített függvény, ami egy immutable számsorozatot hoz létre

# %%
range(10)
# Out:
# range(0, 10)

# %% [markdown]
# A `range` függvény vár egy kezdőértéket, egy végértéket és egy lépésközt, ahol az első és az utolsó opcionális. A vége nem tartozik a range-hez. Ezt majd látni fogjuk a `slice` operátornál, Pythonban listából, sztringekből és általában a lineáris adatszerkezetekből ki lehet jelölni intervallumokat / szakaszokat, ahol a végpont soha nem tartozik a kijelölt részhez.
#
# A kapott `range` objektum a memóriában nagyon kis helyet foglal, azaz `range(1_000_000)` nem csinál egy egymillió hosszúságú listát a memóriában.

# %% [markdown]
# ## For ciklus
#
# az iterációk száma előre ismert.

# %%
for x in range(5):
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for y in range(2, 10, 3):
    print(y)
# Out:
# 2
# 5
# 8

# %%
for x in reversed(range(2, 10, 2)):
    print(x)
# Out:
# 8
# 6
# 4
# 2

# %%
for x in range(8, 1, -2):
    print(x)
# Out:
# 8
# 6
# 4
# 2

# %% [markdown]
# ## while
#
#  addig iterálunk, amíg valamilyen feltétel teljesül.

# %%
i = 0
while i < 5:
    print(i)
    i = i + 1
i
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Nincs `do...while` Pythonban.

# %% [markdown]
# ## break és continue
#
# - `break`: ha korábban ki akarunk lépni egy ciklusból
# - `continue`: ha korábban szeretnénk a következő ciklus futásra lépni

# %%
for i in range(10):
    if i % 2 == 0:
        continue
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(10):
    if i > 4:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
s = "parallelepipedon"

for c in s:
    print(c)
# Out:
# p
# a
# r
# a
# l
# l
# e
# l
# e
# p
# i
# p
# e
# d
# o
# n

# %% [markdown]
# ### Idiomatikus kód
#
# Mit jelent ez? Minden nyelven vannak a nyelv által biztosított lehetőségek és ezek között vannak kitüntetettek, azok, ahogy az adott feladatot **meg szokás oldani** az adott nyelvre jellemző módon.
#
# Pythonban is lehet C-szerű, Java-szerű kódot írni, de nem javasolt. Ehelyett, mindig van egy olyan megoldás, ami a leginkább Python-os, ekkor szokás azt mondani, hogy a kód "Pythonic", azaz Python-szerű.

# %%
s = "Hello"

# Not pythonic
ix = 0
while ix < len(s):
    char = s[ix]
    ix = ix + 1
    print(char)
# Out:
# H
# e
# l
# l
# o

# %%
# Not pythonic
for ix in range(len(s)):
    char = s[ix]
    print(char)
# Out:
# H
# e
# l
# l
# o

# %%
# pythonic way:

for char in s:
    print(char)
# Out:
# H
# e
# l
# l
# o

# %%
# Ha nem fontos a ciklusváltozó aktuális értéke, 
#akkor azt aláhúzásjellel szokás jelölni:

text = "Hello, world!"

for _ in range(5):
    print(text)
# Out:
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
